# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cmu = pd.read_csv('datasets/cmu/data.csv')

# %%
cmu.dtypes.head(8)
# Out:
# subject          object
# sessionIndex      int64
# rep               int64
# H.period        float64
# DD.period.t     float64
# UD.period.t     float64
# H.t             float64
# DD.t.i          float64
# dtype: object

# %%
cmu.dtypes.tail(8)
# Out:
# UD.a.n         float64
# H.n            float64
# DD.n.l         float64
# UD.n.l         float64
# H.l            float64
# DD.l.Return    float64
# UD.l.Return    float64
# H.Return       float64
# dtype: object

# %%
cmu.head(8)
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
# 5    s002             1    6    0.1394       0.2343       0.0949  0.0813
# 6    s002             1    7    0.1064       0.2069       0.1005  0.0866
# 7    s002             1    8    0.0929       0.1810       0.0881  0.0818
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# ...

# %%
cmu.tail(8)
# Out:
#       subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 20392    s057             8   43    0.0665       0.0678       0.0013  0.0902
# 20393    s057             8   44    0.0834       0.1147       0.0313  0.1002
# 20394    s057             8   45    0.0918       0.1018       0.0100  0.0802
# 20395    s057             8   46    0.0884       0.0685      -0.0199  0.1095
# 20396    s057             8   47    0.0655       0.0630      -0.0025  0.0910
# 20397    s057             8   48    0.0939       0.1189       0.0250  0.1008
# 20398    s057             8   49    0.0923       0.1294       0.0371  0.0913
# 20399    s057             8   50    0.0596       0.1310       0.0714  0.0992
#
#        DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 20392  0.1601  0.0699  0.0515  ...  0.1031  0.0765 -0.0266  0.0768  0.0622
# 20393  0.1055  0.0053  0.0744  ...  0.0971  0.0929 -0.0042  0.0520  0.0406
# ...

# %%
cmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20400 entries, 0 to 20399
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subject          20400 non-null  object
#  1   sessionIndex     20400 non-null  int64
#  2   rep              20400 non-null  int64
#  3   H.period         20400 non-null  float64
#  4   DD.period.t      20400 non-null  float64
#  5   UD.period.t      20400 non-null  float64
#  6   H.t              20400 non-null  float64
#  7   DD.t.i           20400 non-null  float64
#  8   UD.t.i           20400 non-null  float64
#  9   H.i              20400 non-null  float64
#  10  DD.i.e           20400 non-null  float64
#  11  UD.i.e           20400 non-null  float64
#  12  H.e              20400 non-null  float64
#  13  DD.e.five        20400 non-null  float64
#  14  UD.e.five        20400 non-null  float64
#  15  H.five           20400 non-null  float64
# ...

# %%
cmu.shape
# Out:
# (20400, 34)

# %%
cmu["UD.five.Shift.r"].head(8)
# Out:
# 0    1.4909
# 1    0.7133
# 2    0.5311
# 3    1.1651
# 4    0.8213
# 5    0.9954
# 6    1.1150
# 7    1.0503
# Name: UD.five.Shift.r, dtype: float64

# %%
type(cmu["UD.five.Shift.r"])
# Out:
# pandas.core.series.Series

# %%
cmu["UD.five.Shift.r"].tail(8)
# Out:
# 20392    0.1868
# 20393    0.2259
# 20394    0.5777
# 20395    0.1398
# 20396    0.1454
# 20397    0.1457
# 20398    0.2061
# 20399    0.1694
# Name: UD.five.Shift.r, dtype: float64

# %%
print(cmu["UD.five.Shift.r"].mean())
print(cmu["UD.five.Shift.r"].std())
print(cmu["UD.five.Shift.r"].min())
# Out:
# 0.3619829019607843
# 0.260885855224387
# 0.0856

# %%
cmu["UD.five.Shift.r"].describe()
# Out:
# count    20400.000000
# mean         0.361983
# std          0.260886
# min          0.085600
# 25%          0.229675
# 50%          0.302000
# 75%          0.408900
# max          8.290800
# Name: UD.five.Shift.r, dtype: float64

# %%
cmu["UD.five.Shift.r"].shape
# Out:
# (20400,)

# %%
cmu[['H.i', 'H.t']].head(8)
# Out:
#       H.i     H.t
# 0  0.1169  0.1069
# 1  0.0908  0.0694
# 2  0.0821  0.0731
# 3  0.1040  0.1059
# 4  0.0903  0.0895
# 5  0.0744  0.0813
# 6  0.0800  0.0866
# 7  0.0747  0.0818

# %%
type(cmu[['H.i', 'H.t']])
# Out:
# pandas.core.frame.DataFrame

# %%
cmu[['H.i', 'H.t']].describe()
# Out:
#                 H.i           H.t
# count  20400.000000  20400.000000
# mean       0.081565      0.085727
# std        0.026887      0.027424
# min        0.003200      0.009300
# 25%        0.062000      0.066000
# 50%        0.077100      0.081000
# 75%        0.096900      0.099800
# max        0.331200      0.241100

# %%
above_mean = cmu[cmu["UD.five.Shift.r"] > cmu["UD.five.Shift.r"].mean()]
above_mean.head(8)
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
# 5    s002             1    6    0.1394       0.2343       0.0949  0.0813
# 6    s002             1    7    0.1064       0.2069       0.1005  0.0866
# 7    s002             1    8    0.0929       0.1810       0.0881  0.0818
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# ...

# %%
cmu["UD.five.Shift.r"] > cmu["UD.five.Shift.r"].mean()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 20395    False
# 20396    False
# 20397    False
# 20398    False
# 20399    False
# Name: UD.five.Shift.r, Length: 20400, dtype: bool

# %%
above_mean_hs = cmu.loc[cmu["UD.five.Shift.r"] > cmu["UD.five.Shift.r"].mean(), ["H.t", "H.i"]] 
above_mean_hs.head(8)
# Out:
#       H.t     H.i
# 0  0.1069  0.1169
# 1  0.0694  0.0908
# 2  0.0731  0.0821
# 3  0.1059  0.1040
# 4  0.0895  0.0903
# 5  0.0813  0.0744
# 6  0.0866  0.0800
# 7  0.0818  0.0747

# %%
subcmu = cmu.iloc[0:8, 0:4]
subcmu
# Out:
#   subject  sessionIndex  rep  H.period
# 0    s002             1    1    0.1491
# 1    s002             1    2    0.1111
# 2    s002             1    3    0.1328
# 3    s002             1    4    0.1291
# 4    s002             1    5    0.1249
# 5    s002             1    6    0.1394
# 6    s002             1    7    0.1064
# 7    s002             1    8    0.0929

# %%
cmu[["H.i", "H.t"]].plot(subplots=True, figsize=(20, 4))
plt.show()

# %%
cmu.plot.scatter(x="UD.five.Shift.r", y="H.t", alpha=0.5)
# Out:
# <Axes: xlabel='UD.five.Shift.r', ylabel='H.t'>

# %%
cmu["UD.five.Shift.r"].plot.box()
plt.show()
